# %% [markdown]
# # Guided Attention Quickstart
# Runs simple example of Guided Attention.

# %%
# !nvcc --version
# !pip freeze
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# !git clone https://github.com/jackBonadies/Guided-Attention.git
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:33:58_PDT_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0
# absl-py==1.4.0
# alabaster==0.7.13
# albumentations==1.2.1
# altair==4.2.2
# anyio==3.6.2
# appdirs==1.4.4
# argon2-cffi==21.3.0
# argon2-cffi-bindings==21.2.0
# arviz==0.15.1
# astropy==5.2.2
# astunparse==1.6.3
# attrs==22.2.0
# audioread==3.0.0
# autograd==1.5
# Babel==2.12.1
# backcall==0.2.0
# beautifulsoup4==4.11.2
# bleach==6.0.0
# blis==0.7.9
# blosc2==2.0.0
# bokeh==2.4.3
# branca==0.6.0
# CacheControl==0.12.11
# cached-property==1.5.2
# cachetools==5.3.0
# catalogue==2.0.8
# certifi==2022.12.7
# cffi==1.15.1
# chardet==4.0.0
# charset-normalizer==2.0.12
# chex==0.1.7
# click==8.1.3
# cloudpickle==2.2.1
# cmake==3.25.2
# cmdstanpy==1.1.0
# colorcet==3.0.1
# colorlover==0.3.0
# community==1.0.0b1
# confection==0.0.4
# cons==0.4.5
# contextlib2==0.6.0.post1
# contourpy==1.0.7
# convertdate==2.4.0
# cryptography==40.0.1
# cufflinks==0.17.3
# cupy-cuda11x==11.0.0
# cvxopt==1.3.0
# cvxpy==1.3.1
# cycler==0.11.0
# cymem==2.0.7
# Cython==0.29.34
# dask==2022.12.1
# datascience==0.17.6
# db-dtypes==1.1.1
# dbus-python==1.2.16
# debugpy==1.6.6
# decorator==4.4.2
# defusedxml==0.7.1
# distributed==2022.12.1
# dlib==19.24.1
# dm-tree==0.1.8
# docutils==0.16
# dopamine-rl==4.0.6
# earthengine-api==0.1.348
# easydict==1.10
# ecos==2.0.12
# editdistance==0.6.2
# en-core-web-sm @ https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.5.0/en_core_web_sm-3.5.0-py3-none-any.whl
# entrypoints==0.4
# ephem==4.1.4
# et-xmlfile==1.1.0
# etils==1.2.0
# etuples==0.3.8
# exceptiongroup==1.1.1
# fastai==2.7.12
# fastcore==1.5.29
# fastdownload==0.0.7
# fastjsonschema==2.16.3
# fastprogress==1.0.3
# fastrlock==0.8.1
# filelock==3.11.0
# firebase-admin==5.3.0
# Flask==2.2.3
# flatbuffers==23.3.3
# flax==0.6.8
# folium==0.14.0
# fonttools==4.39.3
# frozendict==2.3.7
# fsspec==2023.4.0
# future==0.18.3
# gast==0.4.0
# GDAL==3.3.2
# gdown==4.6.6
# gensim==4.3.1
# geographiclib==2.0
# geopy==2.3.0
# gin-config==0.5.0
# glob2==0.7
# google==2.0.3
# google-api-core==2.11.0
# google-api-python-client==2.84.0
# google-auth==2.17.2
# google-auth-httplib2==0.1.0
# google-auth-oauthlib==1.0.0
# google-cloud-bigquery==3.9.0
# google-cloud-bigquery-storage==2.19.1
# google-cloud-core==2.3.2
# google-cloud-datastore==2.15.1
# google-cloud-firestore==2.11.0
# google-cloud-language==2.9.1
# google-cloud-storage==2.8.0
# google-cloud-translate==3.11.1
# google-colab @ file:///colabtools/dist/google-colab-1.0.0.tar.gz
# google-crc32c==1.5.0
# google-pasta==0.2.0
# google-resumable-media==2.4.1
# googleapis-common-protos==1.59.0
# googledrivedownloader==0.4
# graphviz==0.20.1
# greenlet==2.0.2
# grpcio==1.53.0
# grpcio-status==1.48.2
# gspread==3.4.2
# gspread-dataframe==3.0.8
# gym==0.25.2
# gym-notices==0.0.8
# h5netcdf==1.1.0
# h5py==3.8.0
# HeapDict==1.0.1
# hijri-converter==2.2.4
# holidays==0.22
# holoviews==1.15.4
# html5lib==1.1
# httpimport==1.3.0
# httplib2==0.21.0
# humanize==4.6.0
# hyperopt==0.2.7
# idna==3.4
# imageio==2.25.1
# imageio-ffmpeg==0.4.8
# imagesize==1.4.1
# imbalanced-learn==0.10.1
# imgaug==0.4.0
# importlib-metadata==6.3.0
# importlib-resources==5.12.0
# imutils==0.5.4
# inflect==6.0.4
# iniconfig==2.0.0
# intel-openmp==2023.1.0
# ipykernel==5.5.6
# ipython==7.34.0
# ipython-genutils==0.2.0
# ipython-sql==0.4.1
# ipywidgets==7.7.1
# itsdangerous==2.1.2
# jax==0.4.8
# jaxlib @ https://storage.googleapis.com/jax-releases/cuda11/jaxlib-0.4.7+cuda11.cudnn86-cp39-cp39-manylinux2014_x86_64.whl
# jieba==0.42.1
# Jinja2==3.1.2
# joblib==1.2.0
# jsonpickle==3.0.1
# jsonschema==4.3.3
# jupyter-client==6.1.12
# jupyter-console==6.1.0
# jupyter-server==1.23.6
# jupyter_core==5.3.0
# jupyterlab-pygments==0.2.2
# jupyterlab-widgets==3.0.7
# kaggle==1.5.13
# keras==2.12.0
# keras-vis==0.4.1
# kiwisolver==1.4.4
# korean-lunar-calendar==0.3.1
# langcodes==3.3.0
# lazy_loader==0.2
# libclang==16.0.0
# librosa==0.10.0.post2
# lightgbm==3.3.5
# lit==16.0.1
# llvmlite==0.39.1
# locket==1.0.0
# logical-unification==0.4.5
# LunarCalendar==0.0.9
# lxml==4.9.2
# Markdown==3.4.3
# markdown-it-py==2.2.0
# MarkupSafe==2.1.2
# matplotlib==3.7.1
# matplotlib-inline==0.1.6
# matplotlib-venn==0.11.9
# mdurl==0.1.2
# miniKanren==1.0.3
# missingno==0.5.2
# mistune==0.8.4
# mizani==0.8.1
# mkl==2019.0
# ml-dtypes==0.0.4
# mlxtend==0.14.0
# more-itertools==9.1.0
# moviepy==1.0.3
# mpmath==1.3.0
# msgpack==1.0.5
# multipledispatch==0.6.0
# multitasking==0.0.11
# murmurhash==1.0.9
# music21==8.1.0
# natsort==8.3.1
# nbclient==0.7.3
# nbconvert==6.5.4
# nbformat==5.8.0
# nest-asyncio==1.5.6
# networkx==3.1
# nibabel==3.0.2
# nltk==3.8.1
# notebook==6.4.8
# numba==0.56.4
# numexpr==2.8.4
# numpy==1.22.4
# oauth2client==4.1.3
# oauthlib==3.2.2
# opencv-contrib-python==4.7.0.72
# opencv-python==4.7.0.72
# opencv-python-headless==4.7.0.72
# openpyxl==3.0.10
# opt-einsum==3.3.0
# optax==0.1.4
# orbax==0.1.7
# osqp==0.6.2.post0
# packaging==23.0
# palettable==3.3.1
# pandas==1.5.3
# pandas-datareader==0.10.0
# pandas-gbq==0.17.9
# pandocfilters==1.5.0
# panel==0.14.4
# param==1.13.0
# parso==0.8.3
# partd==1.3.0
# pathlib==1.0.1
# pathy==0.10.1
# patsy==0.5.3
# pep517==0.13.0
# pexpect==4.8.0
# pickleshare==0.7.5
# Pillow==8.4.0
# pip-tools==6.6.2
# platformdirs==3.2.0
# plotly==5.13.1
# plotnine==0.10.1
# pluggy==1.0.0
# pooch==1.6.0
# portpicker==1.3.9
# prefetch-generator==1.0.3
# preshed==3.0.8
# prettytable==0.7.2
# proglog==0.1.10
# progressbar2==4.2.0
# prometheus-client==0.16.0
# promise==2.3
# prompt-toolkit==3.0.38
# prophet==1.1.2
# proto-plus==1.22.2
# protobuf==3.20.3
# psutil==5.9.4
# psycopg2==2.9.6
# ptyprocess==0.7.0
# py-cpuinfo==9.0.0
# py4j==0.10.9.7
# pyarrow==9.0.0
# pyasn1==0.4.8
# pyasn1-modules==0.2.8
# pycocotools==2.0.6
# pycparser==2.21
# pyct==0.5.0
# pydantic==1.10.7
# pydata-google-auth==1.7.0
# pydot==1.4.2
# pydot-ng==2.0.0
# pydotplus==2.0.2
# PyDrive==1.3.1
# pyerfa==2.0.0.3
# pygame==2.3.0
# Pygments==2.14.0
# PyGObject==3.36.0
# pymc==5.1.2
# PyMeeus==0.5.12
# pymystem3==0.2.0
# PyOpenGL==3.1.6
# pyparsing==3.0.9
# pyrsistent==0.19.3
# PySocks==1.7.1
# pytensor==2.10.1
# pytest==7.2.2
# python-apt==0.0.0
# python-dateutil==2.8.2
# python-louvain==0.16
# python-slugify==8.0.1
# python-utils==3.5.2
# pytz==2022.7.1
# pytz-deprecation-shim==0.1.0.post0
# pyviz-comms==2.2.1
# PyWavelets==1.4.1
# PyYAML==6.0
# pyzmq==23.2.1
# qdldl==0.1.7
# qudida==0.0.4
# regex==2022.10.31
# requests==2.27.1
# requests-oauthlib==1.3.1
# requests-unixsocket==0.2.0
# rich==13.3.3
# rpy2==3.5.5
# rsa==4.9
# scikit-image==0.19.3
# scikit-learn==1.2.2
# scipy==1.10.1
# scs==3.2.3
# seaborn==0.12.2
# Send2Trash==1.8.0
# shapely==2.0.1
# six==1.16.0
# sklearn-pandas==2.2.0
# smart-open==6.3.0
# sniffio==1.3.0
# snowballstemmer==2.2.0
# sortedcontainers==2.4.0
# soundfile==0.12.1
# soupsieve==2.4
# soxr==0.3.5
# spacy==3.5.1
# spacy-legacy==3.0.12
# spacy-loggers==1.0.4
# Sphinx==3.5.4
# sphinxcontrib-applehelp==1.0.4
# sphinxcontrib-devhelp==1.0.2
# sphinxcontrib-htmlhelp==2.0.1
# sphinxcontrib-jsmath==1.0.1
# sphinxcontrib-qthelp==1.0.3
# sphinxcontrib-serializinghtml==1.1.5
# SQLAlchemy==2.0.9
# sqlparse==0.4.3
# srsly==2.4.6
# statsmodels==0.13.5
# sympy==1.11.1
# tables==3.8.0
# tabulate==0.8.10
# tblib==1.7.0
# tenacity==8.2.2
# tensorboard==2.12.1
# tensorboard-data-server==0.7.0
# tensorboard-plugin-wit==1.8.1
# tensorflow==2.12.0
# tensorflow-datasets==4.8.3
# tensorflow-estimator==2.12.0
# tensorflow-gcs-config==2.12.0
# tensorflow-hub==0.13.0
# tensorflow-io-gcs-filesystem==0.32.0
# tensorflow-metadata==1.13.0
# tensorflow-probability==0.19.0
# tensorstore==0.1.35
# termcolor==2.2.0
# terminado==0.17.1
# text-unidecode==1.3
# textblob==0.17.1
# tf-slim==1.1.0
# thinc==8.1.9
# threadpoolctl==3.1.0
# tifffile==2023.3.21
# tinycss2==1.2.1
# toml==0.10.2
# tomli==2.0.1
# toolz==0.12.0
# torch @ https://download.pytorch.org/whl/cu118/torch-2.0.0%2Bcu118-cp39-cp39-linux_x86_64.whl
# torchaudio @ https://download.pytorch.org/whl/cu118/torchaudio-2.0.1%2Bcu118-cp39-cp39-linux_x86_64.whl
# torchdata==0.6.0
# torchsummary==1.5.1
# torchtext==0.15.1
# torchvision @ https://download.pytorch.org/whl/cu118/torchvision-0.15.1%2Bcu118-cp39-cp39-linux_x86_64.whl
# tornado==6.2
# tqdm==4.65.0
# traitlets==5.7.1
# triton==2.0.0
# tweepy==4.13.0
# typer==0.7.0
# typing_extensions==4.5.0
# tzdata==2023.3
# tzlocal==4.3
# uritemplate==4.1.1
# urllib3==1.26.15
# vega-datasets==0.9.0
# wasabi==1.1.1
# wcwidth==0.2.6
# webcolors==1.13
# webencodings==0.5.1
# websocket-client==1.5.1
# Werkzeug==2.2.3
# widgetsnbextension==3.6.4
# wordcloud==1.8.2.2
# wrapt==1.14.1
# xarray==2022.12.0
# xarray-einstats==0.5.1
# xgboost==1.7.5
# xlrd==2.0.1
# yellowbrick==1.5
# yfinance==0.2.17
# zict==2.2.0
# zipp==3.15.0
# Looking in indexes: https://download.pytorch.org/whl/cu118, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch in /usr/local/lib/python3.9/dist-packages (2.0.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (0.15.1+cu118)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.9/dist-packages (2.0.1+cu118)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from torch) (3.11.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch) (3.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch) (1.11.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch) (16.0.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch) (3.25.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from torchvision) (2.27.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from torchvision) (1.22.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision) (2022.12.7)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch) (1.3.0)
# Cloning into 'Guided-Attention'...
# remote: Enumerating objects: 230, done.
# remote: Counting objects: 100% (230/230), done.
# remote: Compressing objects: 100% (136/136), done.
# remote: Total 230 (delta 126), reused 191 (delta 91), pack-reused 0
# Receiving objects: 100% (230/230), 18.37 MiB | 21.16 MiB/s, done.
# Resolving deltas: 100% (126/126), done.

# %%
# %cd Guided-Attention
# !ls
# !pip install -r environment/requirements.txt
# !pip freeze
# Out:
# /content/Guided-Attention
# config.py    gui.py   pipeline_guided_attention.py  resource  utils
# environment  LICENSE  README.md			    run.py    web_ui.html
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.9/dist-packages (from -r environment/requirements.txt (line 2)) (4.7.0.72)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.9/dist-packages (from -r environment/requirements.txt (line 3)) (7.7.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from -r environment/requirements.txt (line 4)) (3.7.1)
# Collecting pyrallis
#   Downloading pyrallis-0.3.1-py3-none-any.whl (33 kB)
# Requirement already satisfied: Flask==2.2.3 in /usr/local/lib/python3.9/dist-packages (from -r environment/requirements.txt (line 6)) (2.2.3)
# Collecting diffusers==0.12.1
#   Downloading diffusers-0.12.1-py3-none-any.whl (604 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 604.0/604.0 kB 21.3 MB/s eta 0:00:00
# Collecting transformers==4.26.0
#   Downloading transformers-4.26.0-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 94.5 MB/s eta 0:00:00
# Collecting jupyter
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Collecting accelerate
#   Downloading accelerate-0.18.0-py3-none-any.whl (215 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.3/215.3 kB 25.0 MB/s eta 0:00:00
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.9/dist-packages (from Flask==2.2.3->-r environment/requirements.txt (line 6)) (2.2.3)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.9/dist-packages (from Flask==2.2.3->-r environment/requirements.txt (line 6)) (3.1.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.9/dist-packages (from Flask==2.2.3->-r environment/requirements.txt (line 6)) (8.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.9/dist-packages (from Flask==2.2.3->-r environment/requirements.txt (line 6)) (2.1.2)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /usr/local/lib/python3.9/dist-packages (from Flask==2.2.3->-r environment/requirements.txt (line 6)) (6.3.0)
# Collecting huggingface-hub>=0.10.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 26.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from diffusers==0.12.1->-r environment/requirements.txt (line 7)) (1.22.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.9/dist-packages (from diffusers==0.12.1->-r environment/requirements.txt (line 7)) (8.4.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from diffusers==0.12.1->-r environment/requirements.txt (line 7)) (2022.10.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from diffusers==0.12.1->-r environment/requirements.txt (line 7)) (3.11.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from diffusers==0.12.1->-r environment/requirements.txt (line 7)) (2.27.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers==4.26.0->-r environment/requirements.txt (line 8)) (6.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers==4.26.0->-r environment/requirements.txt (line 8)) (4.65.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 98.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers==4.26.0->-r environment/requirements.txt (line 8)) (23.0)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.9/dist-packages (from ftfy->-r environment/requirements.txt (line 1)) (0.2.6)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->-r environment/requirements.txt (line 3)) (5.5.6)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->-r environment/requirements.txt (line 3)) (3.0.7)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->-r environment/requirements.txt (line 3)) (7.34.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->-r environment/requirements.txt (line 3)) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->-r environment/requirements.txt (line 3)) (3.6.4)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->-r environment/requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->-r environment/requirements.txt (line 4)) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->-r environment/requirements.txt (line 4)) (5.12.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->-r environment/requirements.txt (line 4)) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->-r environment/requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->-r environment/requirements.txt (line 4)) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->-r environment/requirements.txt (line 4)) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->-r environment/requirements.txt (line 4)) (1.4.4)
# Collecting typing-inspect
#   Downloading typing_inspect-0.8.0-py3-none-any.whl (8.7 kB)
# Collecting qtconsole
#   Downloading qtconsole-5.4.2-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.2/121.2 kB 17.1 MB/s eta 0:00:00
# Requirement already satisfied: notebook in /usr/local/lib/python3.9/dist-packages (from jupyter->-r environment/requirements.txt (line 9)) (6.4.8)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.9/dist-packages (from jupyter->-r environment/requirements.txt (line 9)) (6.1.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.9/dist-packages (from jupyter->-r environment/requirements.txt (line 9)) (6.5.4)
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.9/dist-packages (from accelerate->-r environment/requirements.txt (line 10)) (2.0.0+cu118)
# Requirement already satisfied: psutil in /usr/local/lib/python3.9/dist-packages (from accelerate->-r environment/requirements.txt (line 10)) (5.9.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.10.0->diffusers==0.12.1->-r environment/requirements.txt (line 7)) (4.5.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=3.6.0->Flask==2.2.3->-r environment/requirements.txt (line 6)) (3.15.0)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipykernel>=4.5.1->ipywidgets->-r environment/requirements.txt (line 3)) (6.2)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.9/dist-packages (from ipykernel>=4.5.1->ipywidgets->-r environment/requirements.txt (line 3)) (6.1.12)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->-r environment/requirements.txt (line 3)) (4.8.0)
# Collecting jedi>=0.16
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 83.9 MB/s eta 0:00:00
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->-r environment/requirements.txt (line 3)) (2.14.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->-r environment/requirements.txt (line 3)) (3.0.38)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->-r environment/requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->-r environment/requirements.txt (line 3)) (0.7.5)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->-r environment/requirements.txt (line 3)) (4.4.2)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->-r environment/requirements.txt (line 3)) (0.1.6)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->-r environment/requirements.txt (line 3)) (67.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from Jinja2>=3.0->Flask==2.2.3->-r environment/requirements.txt (line 6)) (2.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->-r environment/requirements.txt (line 4)) (1.16.0)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.4.0->accelerate->-r environment/requirements.txt (line 10)) (2.0.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch>=1.4.0->accelerate->-r environment/requirements.txt (line 10)) (3.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch>=1.4.0->accelerate->-r environment/requirements.txt (line 10)) (1.11.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.4.0->accelerate->-r environment/requirements.txt (line 10)) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.4.0->accelerate->-r environment/requirements.txt (line 10)) (16.0.1)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.9/dist-packages (from notebook->jupyter->-r environment/requirements.txt (line 9)) (0.17.1)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.9/dist-packages (from notebook->jupyter->-r environment/requirements.txt (line 9)) (1.5.6)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.9/dist-packages (from notebook->jupyter->-r environment/requirements.txt (line 9)) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.9/dist-packages (from notebook->jupyter->-r environment/requirements.txt (line 9)) (1.8.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.9/dist-packages (from notebook->jupyter->-r environment/requirements.txt (line 9)) (0.16.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.9/dist-packages (from notebook->jupyter->-r environment/requirements.txt (line 9)) (5.8.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.9/dist-packages (from notebook->jupyter->-r environment/requirements.txt (line 9)) (5.3.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.9/dist-packages (from notebook->jupyter->-r environment/requirements.txt (line 9)) (23.2.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter->-r environment/requirements.txt (line 9)) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter->-r environment/requirements.txt (line 9)) (0.2.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter->-r environment/requirements.txt (line 9)) (1.5.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter->-r environment/requirements.txt (line 9)) (6.0.0)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter->-r environment/requirements.txt (line 9)) (0.7.3)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter->-r environment/requirements.txt (line 9)) (0.7.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter->-r environment/requirements.txt (line 9)) (1.2.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter->-r environment/requirements.txt (line 9)) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter->-r environment/requirements.txt (line 9)) (4.11.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter->-r environment/requirements.txt (line 9)) (0.8.4)
# Collecting qtpy>=2.0.1
#   Downloading QtPy-2.3.1-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.9/84.9 kB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->diffusers==0.12.1->-r environment/requirements.txt (line 7)) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->diffusers==0.12.1->-r environment/requirements.txt (line 7)) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->diffusers==0.12.1->-r environment/requirements.txt (line 7)) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->diffusers==0.12.1->-r environment/requirements.txt (line 7)) (2.0.12)
# Collecting mypy-extensions>=0.3.0
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->-r environment/requirements.txt (line 3)) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.9/dist-packages (from jupyter-core>=4.6.1->notebook->jupyter->-r environment/requirements.txt (line 9)) (3.2.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.9/dist-packages (from nbformat->notebook->jupyter->-r environment/requirements.txt (line 9)) (4.3.3)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.9/dist-packages (from nbformat->notebook->jupyter->-r environment/requirements.txt (line 9)) (2.16.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->-r environment/requirements.txt (line 3)) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.9/dist-packages (from argon2-cffi->notebook->jupyter->-r environment/requirements.txt (line 9)) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->nbconvert->jupyter->-r environment/requirements.txt (line 9)) (2.4)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/dist-packages (from bleach->nbconvert->jupyter->-r environment/requirements.txt (line 9)) (0.5.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch>=1.4.0->accelerate->-r environment/requirements.txt (line 10)) (1.3.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat->notebook->jupyter->-r environment/requirements.txt (line 9)) (22.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat->notebook->jupyter->-r environment/requirements.txt (line 9)) (0.19.3)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->-r environment/requirements.txt (line 9)) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->-r environment/requirements.txt (line 9)) (2.21)
# Installing collected packages: tokenizers, qtpy, mypy-extensions, jedi, ftfy, typing-inspect, huggingface-hub, transformers, pyrallis, diffusers, qtconsole, jupyter, accelerate
# Successfully installed accelerate-0.18.0 diffusers-0.12.1 ftfy-6.1.1 huggingface-hub-0.13.4 jedi-0.18.2 jupyter-1.0.0 mypy-extensions-1.0.0 pyrallis-0.3.1 qtconsole-5.4.2 qtpy-2.3.1 tokenizers-0.13.3 transformers-4.26.0 typing-inspect-0.8.0
# absl-py==1.4.0
# accelerate==0.18.0
# alabaster==0.7.13
# albumentations==1.2.1
# altair==4.2.2
# anyio==3.6.2
# appdirs==1.4.4
# argon2-cffi==21.3.0
# argon2-cffi-bindings==21.2.0
# arviz==0.15.1
# astropy==5.2.2
# astunparse==1.6.3
# attrs==22.2.0
# audioread==3.0.0
# autograd==1.5
# Babel==2.12.1
# backcall==0.2.0
# beautifulsoup4==4.11.2
# bleach==6.0.0
# blis==0.7.9
# blosc2==2.0.0
# bokeh==2.4.3
# branca==0.6.0
# CacheControl==0.12.11
# cached-property==1.5.2
# cachetools==5.3.0
# catalogue==2.0.8
# certifi==2022.12.7
# cffi==1.15.1
# chardet==4.0.0
# charset-normalizer==2.0.12
# chex==0.1.7
# click==8.1.3
# cloudpickle==2.2.1
# cmake==3.25.2
# cmdstanpy==1.1.0
# colorcet==3.0.1
# colorlover==0.3.0
# community==1.0.0b1
# confection==0.0.4
# cons==0.4.5
# contextlib2==0.6.0.post1
# contourpy==1.0.7
# convertdate==2.4.0
# cryptography==40.0.1
# cufflinks==0.17.3
# cupy-cuda11x==11.0.0
# cvxopt==1.3.0
# cvxpy==1.3.1
# cycler==0.11.0
# cymem==2.0.7
# Cython==0.29.34
# dask==2022.12.1
# datascience==0.17.6
# db-dtypes==1.1.1
# dbus-python==1.2.16
# debugpy==1.6.6
# decorator==4.4.2
# defusedxml==0.7.1
# diffusers==0.12.1
# distributed==2022.12.1
# dlib==19.24.1
# dm-tree==0.1.8
# docutils==0.16
# dopamine-rl==4.0.6
# earthengine-api==0.1.348
# easydict==1.10
# ecos==2.0.12
# editdistance==0.6.2
# en-core-web-sm @ https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.5.0/en_core_web_sm-3.5.0-py3-none-any.whl
# entrypoints==0.4
# ephem==4.1.4
# et-xmlfile==1.1.0
# etils==1.2.0
# etuples==0.3.8
# exceptiongroup==1.1.1
# fastai==2.7.12
# fastcore==1.5.29
# fastdownload==0.0.7
# fastjsonschema==2.16.3
# fastprogress==1.0.3
# fastrlock==0.8.1
# filelock==3.11.0
# firebase-admin==5.3.0
# Flask==2.2.3
# flatbuffers==23.3.3
# flax==0.6.8
# folium==0.14.0
# fonttools==4.39.3
# frozendict==2.3.7
# fsspec==2023.4.0
# ftfy==6.1.1
# future==0.18.3
# gast==0.4.0
# GDAL==3.3.2
# gdown==4.6.6
# gensim==4.3.1
# geographiclib==2.0
# geopy==2.3.0
# gin-config==0.5.0
# glob2==0.7
# google==2.0.3
# google-api-core==2.11.0
# google-api-python-client==2.84.0
# google-auth==2.17.2
# google-auth-httplib2==0.1.0
# google-auth-oauthlib==1.0.0
# google-cloud-bigquery==3.9.0
# google-cloud-bigquery-storage==2.19.1
# google-cloud-core==2.3.2
# google-cloud-datastore==2.15.1
# google-cloud-firestore==2.11.0
# google-cloud-language==2.9.1
# google-cloud-storage==2.8.0
# google-cloud-translate==3.11.1
# google-colab @ file:///colabtools/dist/google-colab-1.0.0.tar.gz
# google-crc32c==1.5.0
# google-pasta==0.2.0
# google-resumable-media==2.4.1
# googleapis-common-protos==1.59.0
# googledrivedownloader==0.4
# graphviz==0.20.1
# greenlet==2.0.2
# grpcio==1.53.0
# grpcio-status==1.48.2
# gspread==3.4.2
# gspread-dataframe==3.0.8
# gym==0.25.2
# gym-notices==0.0.8
# h5netcdf==1.1.0
# h5py==3.8.0
# HeapDict==1.0.1
# hijri-converter==2.2.4
# holidays==0.22
# holoviews==1.15.4
# html5lib==1.1
# httpimport==1.3.0
# httplib2==0.21.0
# huggingface-hub==0.13.4
# humanize==4.6.0
# hyperopt==0.2.7
# idna==3.4
# imageio==2.25.1
# imageio-ffmpeg==0.4.8
# imagesize==1.4.1
# imbalanced-learn==0.10.1
# imgaug==0.4.0
# importlib-metadata==6.3.0
# importlib-resources==5.12.0
# imutils==0.5.4
# inflect==6.0.4
# iniconfig==2.0.0
# intel-openmp==2023.1.0
# ipykernel==5.5.6
# ipython==7.34.0
# ipython-genutils==0.2.0
# ipython-sql==0.4.1
# ipywidgets==7.7.1
# itsdangerous==2.1.2
# jax==0.4.8
# jaxlib @ https://storage.googleapis.com/jax-releases/cuda11/jaxlib-0.4.7+cuda11.cudnn86-cp39-cp39-manylinux2014_x86_64.whl
# jedi==0.18.2
# jieba==0.42.1
# Jinja2==3.1.2
# joblib==1.2.0
# jsonpickle==3.0.1
# jsonschema==4.3.3
# jupyter==1.0.0
# jupyter-client==6.1.12
# jupyter-console==6.1.0
# jupyter-server==1.23.6
# jupyter_core==5.3.0
# jupyterlab-pygments==0.2.2
# jupyterlab-widgets==3.0.7
# kaggle==1.5.13
# keras==2.12.0
# keras-vis==0.4.1
# kiwisolver==1.4.4
# korean-lunar-calendar==0.3.1
# langcodes==3.3.0
# lazy_loader==0.2
# libclang==16.0.0
# librosa==0.10.0.post2
# lightgbm==3.3.5
# lit==16.0.1
# llvmlite==0.39.1
# locket==1.0.0
# logical-unification==0.4.5
# LunarCalendar==0.0.9
# lxml==4.9.2
# Markdown==3.4.3
# markdown-it-py==2.2.0
# MarkupSafe==2.1.2
# matplotlib==3.7.1
# matplotlib-inline==0.1.6
# matplotlib-venn==0.11.9
# mdurl==0.1.2
# miniKanren==1.0.3
# missingno==0.5.2
# mistune==0.8.4
# mizani==0.8.1
# mkl==2019.0
# ml-dtypes==0.0.4
# mlxtend==0.14.0
# more-itertools==9.1.0
# moviepy==1.0.3
# mpmath==1.3.0
# msgpack==1.0.5
# multipledispatch==0.6.0
# multitasking==0.0.11
# murmurhash==1.0.9
# music21==8.1.0
# mypy-extensions==1.0.0
# natsort==8.3.1
# nbclient==0.7.3
# nbconvert==6.5.4
# nbformat==5.8.0
# nest-asyncio==1.5.6
# networkx==3.1
# nibabel==3.0.2
# nltk==3.8.1
# notebook==6.4.8
# numba==0.56.4
# numexpr==2.8.4
# numpy==1.22.4
# oauth2client==4.1.3
# oauthlib==3.2.2
# opencv-contrib-python==4.7.0.72
# opencv-python==4.7.0.72
# opencv-python-headless==4.7.0.72
# openpyxl==3.0.10
# opt-einsum==3.3.0
# optax==0.1.4
# orbax==0.1.7
# osqp==0.6.2.post0
# packaging==23.0
# palettable==3.3.1
# pandas==1.5.3
# pandas-datareader==0.10.0
# pandas-gbq==0.17.9
# pandocfilters==1.5.0
# panel==0.14.4
# param==1.13.0
# parso==0.8.3
# partd==1.3.0
# pathlib==1.0.1
# pathy==0.10.1
# patsy==0.5.3
# pep517==0.13.0
# pexpect==4.8.0
# pickleshare==0.7.5
# Pillow==8.4.0
# pip-tools==6.6.2
# platformdirs==3.2.0
# plotly==5.13.1
# plotnine==0.10.1
# pluggy==1.0.0
# pooch==1.6.0
# portpicker==1.3.9
# prefetch-generator==1.0.3
# preshed==3.0.8
# prettytable==0.7.2
# proglog==0.1.10
# progressbar2==4.2.0
# prometheus-client==0.16.0
# promise==2.3
# prompt-toolkit==3.0.38
# prophet==1.1.2
# proto-plus==1.22.2
# protobuf==3.20.3
# psutil==5.9.4
# psycopg2==2.9.6
# ptyprocess==0.7.0
# py-cpuinfo==9.0.0
# py4j==0.10.9.7
# pyarrow==9.0.0
# pyasn1==0.4.8
# pyasn1-modules==0.2.8
# pycocotools==2.0.6
# pycparser==2.21
# pyct==0.5.0
# pydantic==1.10.7
# pydata-google-auth==1.7.0
# pydot==1.4.2
# pydot-ng==2.0.0
# pydotplus==2.0.2
# PyDrive==1.3.1
# pyerfa==2.0.0.3
# pygame==2.3.0
# Pygments==2.14.0
# PyGObject==3.36.0
# pymc==5.1.2
# PyMeeus==0.5.12
# pymystem3==0.2.0
# PyOpenGL==3.1.6
# pyparsing==3.0.9
# pyrallis==0.3.1
# pyrsistent==0.19.3
# PySocks==1.7.1
# pytensor==2.10.1
# pytest==7.2.2
# python-apt==0.0.0
# python-dateutil==2.8.2
# python-louvain==0.16
# python-slugify==8.0.1
# python-utils==3.5.2
# pytz==2022.7.1
# pytz-deprecation-shim==0.1.0.post0
# pyviz-comms==2.2.1
# PyWavelets==1.4.1
# PyYAML==6.0
# pyzmq==23.2.1
# qdldl==0.1.7
# qtconsole==5.4.2
# QtPy==2.3.1
# qudida==0.0.4
# regex==2022.10.31
# requests==2.27.1
# requests-oauthlib==1.3.1
# requests-unixsocket==0.2.0
# rich==13.3.3
# rpy2==3.5.5
# rsa==4.9
# scikit-image==0.19.3
# scikit-learn==1.2.2
# scipy==1.10.1
# scs==3.2.3
# seaborn==0.12.2
# Send2Trash==1.8.0
# shapely==2.0.1
# six==1.16.0
# sklearn-pandas==2.2.0
# smart-open==6.3.0
# sniffio==1.3.0
# snowballstemmer==2.2.0
# sortedcontainers==2.4.0
# soundfile==0.12.1
# soupsieve==2.4
# soxr==0.3.5
# spacy==3.5.1
# spacy-legacy==3.0.12
# spacy-loggers==1.0.4
# Sphinx==3.5.4
# sphinxcontrib-applehelp==1.0.4
# sphinxcontrib-devhelp==1.0.2
# sphinxcontrib-htmlhelp==2.0.1
# sphinxcontrib-jsmath==1.0.1
# sphinxcontrib-qthelp==1.0.3
# sphinxcontrib-serializinghtml==1.1.5
# SQLAlchemy==2.0.9
# sqlparse==0.4.3
# srsly==2.4.6
# statsmodels==0.13.5
# sympy==1.11.1
# tables==3.8.0
# tabulate==0.8.10
# tblib==1.7.0
# tenacity==8.2.2
# tensorboard==2.12.1
# tensorboard-data-server==0.7.0
# tensorboard-plugin-wit==1.8.1
# tensorflow==2.12.0
# tensorflow-datasets==4.8.3
# tensorflow-estimator==2.12.0
# tensorflow-gcs-config==2.12.0
# tensorflow-hub==0.13.0
# tensorflow-io-gcs-filesystem==0.32.0
# tensorflow-metadata==1.13.0
# tensorflow-probability==0.19.0
# tensorstore==0.1.35
# termcolor==2.2.0
# terminado==0.17.1
# text-unidecode==1.3
# textblob==0.17.1
# tf-slim==1.1.0
# thinc==8.1.9
# threadpoolctl==3.1.0
# tifffile==2023.3.21
# tinycss2==1.2.1
# tokenizers==0.13.3
# toml==0.10.2
# tomli==2.0.1
# toolz==0.12.0
# torch @ https://download.pytorch.org/whl/cu118/torch-2.0.0%2Bcu118-cp39-cp39-linux_x86_64.whl
# torchaudio @ https://download.pytorch.org/whl/cu118/torchaudio-2.0.1%2Bcu118-cp39-cp39-linux_x86_64.whl
# torchdata==0.6.0
# torchsummary==1.5.1
# torchtext==0.15.1
# torchvision @ https://download.pytorch.org/whl/cu118/torchvision-0.15.1%2Bcu118-cp39-cp39-linux_x86_64.whl
# tornado==6.2
# tqdm==4.65.0
# traitlets==5.7.1
# transformers==4.26.0
# triton==2.0.0
# tweepy==4.13.0
# typer==0.7.0
# typing-inspect==0.8.0
# typing_extensions==4.5.0
# tzdata==2023.3
# tzlocal==4.3
# uritemplate==4.1.1
# urllib3==1.26.15
# vega-datasets==0.9.0
# wasabi==1.1.1
# wcwidth==0.2.6
# webcolors==1.13
# webencodings==0.5.1
# websocket-client==1.5.1
# Werkzeug==2.2.3
# widgetsnbextension==3.6.4
# wordcloud==1.8.2.2
# wrapt==1.14.1
# xarray==2022.12.0
# xarray-einstats==0.5.1
# xgboost==1.7.5
# xlrd==2.0.1
# yellowbrick==1.5
# yfinance==0.2.17
# zict==2.2.0
# zipp==3.15.0

# %%
import pdb
import run
from utils import shared_state
import config
import torch

# %cd Guided-Attention

shared_state.hyperParamOverrides = [{}] #todo cleanup
run_config = config.RunConfig(meta_prompt="a dog and a cat")
run_config.half_precision = True #otherwise, OOM. f16==9.5 vram
shared_state.config = run_config
meta_prompt = "a dog and a cat"

print(meta_prompt)
#shared_state.config.hyperParamDefaults = {}
shared_state.config.meta_prompt = meta_prompt
shared_state.config = run_config

run.setup(shared_state.config)

image_path = run.execute(shared_state.config) #calls run.execute after loading model
# Out:
# [Errno 2] No such file or directory: 'Guided-Attention'
# /content/Guided-Attention
# a dog and a cat
# Fetching 16 files:   0%|          | 0/16 [00:00<?, ?it/s]
# Seed: 42
#   0%|          | 0/50 [00:00<?, ?it/s]
# weighted center col: 7.99609375
# weighted center row: 6.2421875
# weighted center col: 7.68359375
# weighted center row: 6.46875
# weighted center col: 8.3046875
# weighted center row: 9.6484375
# loss for robot: 0.39697265625
# loss for blue: 0.43212890625
# loss for vase: 0.35498046875
# weighted center col: 7.99609375
# weighted center row: 6.2421875
# weighted center col: 7.68359375
# weighted center row: 6.46875
# weighted center col: 8.3046875
# weighted center row: 9.6484375
# loss for robot: 0.39697265625
# loss for blue: 0.43212890625
# loss for vase: 0.35498046875
# gradient size average: 0.0002474784851074219
# weighted center col: 8.3203125
# weighted center row: 6.46484375
# weighted center col: 7.7578125
# weighted center row: 6.74609375
# weighted center col: 8.0234375
# weighted center row: 9.296875
# loss for robot: 0.37548828125
# loss for blue: 0.427734375
# loss for vase: 0.340576171875
# gradient size average: 0.0002827644348144531
# weighted center col: 8.875
# weighted center row: 6.88671875
# weighted center col: 7.8203125
# weighted center row: 7.0
# weighted center col: 7.78125
# weighted center row: 8.8125
# loss for robot: 0.339599609375
# loss for blue: 0.42529296875
# loss for vase: 0.335693359375
# gradient size average: 0.00025653839111328125
# weighted center col: 9.46875
# weighted center row: 7.203125
# weighted center col: 7.8359375
# weighted center row: 7.18359375
# weighted center col: 7.5703125
# weighted center row: 8.6328125
# loss for robot: 0.30517578125
# loss for blue: 0.4228515625
# loss for vase: 0.3310546875
# gradient size average: 0.00024175643920898438
# weighted center col: 9.9140625
# weighted center row: 7.5703125
# weighted center col: 7.85546875
# weighted center row: 7.4375
# weighted center col: 7.453125
# weighted center row: 8.390625
# loss for robot: 0.27587890625
# loss for blue: 0.421630859375
# loss for vase: 0.32958984375
# gradient size average: 0.0002238750457763672
# weighted center col: 10.15625
# weighted center row: 7.9921875
# weighted center col: 7.8515625
# weighted center row: 7.69921875
# weighted center col: 7.4140625
# weighted center row: 8.1171875
# loss for robot: 0.24462890625
# loss for blue: 0.4189453125
# loss for vase: 0.33251953125
# gradient size average: 0.00022935867309570312
# weighted center col: 10.296875
# weighted center row: 8.3125
# weighted center col: 7.8359375
# weighted center row: 7.96875
# weighted center col: 7.44921875
# weighted center row: 7.88671875
# loss for robot: 0.2188720703125
# loss for blue: 0.4150390625
# loss for vase: 0.336669921875
# gradient size average: 0.0001672506332397461
# weighted center col: 10.453125
# weighted center row: 8.4453125
# weighted center col: 7.80859375
# weighted center row: 8.140625
# weighted center col: 7.39453125
# weighted center row: 7.80078125
# loss for robot: 0.20751953125
# loss for blue: 0.4130859375
# loss for vase: 0.336181640625
# gradient size average: 0.00014293193817138672
# weighted center col: 10.5546875
# weighted center row: 8.5390625
# weighted center col: 7.7734375
# weighted center row: 8.28125
# weighted center col: 7.4140625
# weighted center row: 7.71875
# loss for robot: 0.1971435546875
# loss for blue: 0.41015625
# loss for vase: 0.33642578125
# gradient size average: 0.00015425682067871094
# weighted center col: 10.5078125
# weighted center row: 8.65625
# weighted center col: 7.765625
# weighted center row: 8.390625
# weighted center col: 7.49609375
# weighted center row: 7.6796875
# loss for robot: 0.18359375
# loss for blue: 0.40966796875
# loss for vase: 0.338623046875
# gradient size average: 0.00012695789337158203
# weighted center col: 10.609375
# weighted center row: 8.75
# weighted center col: 7.72265625
# weighted center row: 8.4765625
# weighted center col: 7.51171875
# weighted center row: 7.66015625
# loss for robot: 0.1748046875
# loss for blue: 0.408203125
# loss for vase: 0.3388671875
# gradient size average: 0.00013554096221923828
# weighted center col: 10.5859375
# weighted center row: 8.8203125
# weighted center col: 7.6875
# weighted center row: 8.53125
# weighted center col: 7.5703125
# weighted center row: 7.6796875
# loss for robot: 0.164306640625
# loss for blue: 0.406494140625
# loss for vase: 0.34033203125
# gradient size average: 0.00013053417205810547
# weighted center col: 10.8046875
# weighted center row: 8.921875
# weighted center col: 7.640625
# weighted center row: 8.6171875
# weighted center col: 7.48828125
# weighted center row: 7.64453125
# loss for robot: 0.1595458984375
# loss for blue: 0.405517578125
# loss for vase: 0.338623046875
# gradient size average: 0.00010263919830322266
# weighted center col: 10.84375
# weighted center row: 8.9296875
# weighted center col: 7.62890625
# weighted center row: 8.6875
# weighted center col: 7.52734375
# weighted center row: 7.64453125
# loss for robot: 0.1539306640625
# loss for blue: 0.404296875
# loss for vase: 0.339599609375
# gradient size average: 9.1552734375e-05
# weighted center col: 10.8984375
# weighted center row: 8.96875
# weighted center col: 7.55859375
# weighted center row: 8.765625
# weighted center col: 7.52734375
# weighted center row: 7.66015625
# loss for robot: 0.1500244140625
# loss for blue: 0.40283203125
# loss for vase: 0.339599609375
# gradient size average: 8.779764175415039e-05
# weighted center col: 10.96875
# weighted center row: 8.96875
# weighted center col: 7.54296875
# weighted center row: 8.8125
# weighted center col: 7.55078125
# weighted center row: 7.6875
# loss for robot: 0.1463623046875
# loss for blue: 0.40234375
# loss for vase: 0.33935546875
# gradient size average: 8.58306884765625e-05
# weighted center col: 11.0234375
# weighted center row: 8.9765625
# weighted center col: 7.49609375
# weighted center row: 8.875
# weighted center col: 7.55078125
# weighted center row: 7.69921875
# loss for robot: 0.1429443359375
# loss for blue: 0.401611328125
# loss for vase: 0.339599609375
# gradient size average: 8.559226989746094e-05
# weighted center col: 11.046875
# weighted center row: 8.9765625
# weighted center col: 7.48046875
# weighted center row: 8.9453125
# weighted center col: 7.5859375
# weighted center row: 7.73046875
# loss for robot: 0.138916015625
# loss for blue: 0.400390625
# loss for vase: 0.339599609375
# gradient size average: 8.672475814819336e-05
# weighted center col: 11.1171875
# weighted center row: 8.984375
# weighted center col: 7.44921875
# weighted center row: 9.0234375
# weighted center col: 7.59765625
# weighted center row: 7.71875
# loss for robot: 0.1346435546875
# loss for blue: 0.399169921875
# loss for vase: 0.33984375
# gradient size average: 8.64863395690918e-05
# weighted center col: 11.1640625
# weighted center row: 8.9921875
# weighted center col: 7.375
# weighted center row: 9.125
# weighted center col: 7.59375
# weighted center row: 7.73828125
# loss for robot: 0.1304931640625
# loss for blue: 0.397705078125
# loss for vase: 0.339599609375
# gradient size average: 8.147954940795898e-05
# weighted center col: 11.2421875
# weighted center row: 9.0234375
# weighted center col: 7.3203125
# weighted center row: 9.21875
# weighted center col: 7.59765625
# weighted center row: 7.734375
# loss for robot: 0.1275634765625
# loss for blue: 0.396728515625
# loss for vase: 0.33935546875
# gradient size average: 0.0001118779182434082
# weighted center col: 11.203125
# weighted center row: 8.9453125
# weighted center col: 7.44921875
# weighted center row: 8.9375
# weighted center col: 7.65234375
# weighted center row: 7.8125
# loss for robot: 0.1246337890625
# loss for blue: 0.39990234375
# loss for vase: 0.33935546875
# gradient size average: 0.0001087188720703125
# weighted center col: 11.3359375
# weighted center row: 9.0859375
# weighted center col: 7.3046875
# weighted center row: 9.0859375
# weighted center col: 7.57421875
# weighted center row: 7.75
# loss for robot: 0.1260986328125
# loss for blue: 0.3974609375
# loss for vase: 0.3369140625
# gradient size average: 0.00011688470840454102
# weighted center col: 11.15625
# weighted center row: 8.9453125
# weighted center col: 7.36328125
# weighted center row: 9.1640625
# weighted center col: 7.65625
# weighted center row: 7.8046875
# loss for robot: 0.1224365234375
# loss for blue: 0.39599609375
# loss for vase: 0.33935546875
# gradient size average: 0.0001366138458251953
# weighted center col: 11.34375
# weighted center row: 9.09375
# weighted center col: 7.19140625
# weighted center row: 9.3671875
# weighted center col: 7.546875
# weighted center row: 7.734375
# loss for robot: 0.1260986328125
# loss for blue: 0.398193359375
# loss for vase: 0.336181640625
# gradient size average: 0.0001862049102783203
# 	 Exceeded max number of iterations (25)!
# weighted center col: 11.1484375
# weighted center row: 8.9375
# weighted center col: 7.42578125
# weighted center row: 8.9921875
# weighted center col: 7.67578125
# weighted center row: 7.83984375
# loss for robot: 0.12103271484375
# loss for blue: 0.3974609375
# loss for vase: 0.3388671875
# 	 Finished with loss of: tensor([0.8574], device='cuda:0', grad_fn=<AddBackward0>)
# loss for robot: 0.12103271484375
# loss for blue: 0.3974609375
# loss for vase: 0.3388671875
# gradient size average: 0.00019788742065429688
# Iteration 0 | Loss: 0.8574
# weighted center col: 11.2265625
# weighted center row: 8.984375
# weighted center col: 7.375
# weighted center row: 8.8359375
# weighted center col: 7.57421875
# weighted center row: 7.828125
# loss for robot: 0.12005615234375
# loss for blue: 0.3984375
# loss for vase: 0.333251953125
# loss for robot: 0.12005615234375
# loss for blue: 0.3984375
# loss for vase: 0.333251953125
# gradient size average: 6.979703903198242e-05
# Iteration 1 | Loss: 0.8516
# weighted center col: 10.8515625
# weighted center row: 8.765625
# weighted center col: 7.609375
# weighted center row: 8.53125
# weighted center col: 7.64453125
# weighted center row: 7.890625
# loss for robot: 0.1361083984375
# loss for blue: 0.39990234375
# loss for vase: 0.331787109375
# weighted center col: 10.8515625
# weighted center row: 8.765625
# weighted center col: 7.609375
# weighted center row: 8.53125
# weighted center col: 7.64453125
# weighted center row: 7.890625
# loss for robot: 0.1361083984375
# loss for blue: 0.39990234375
# loss for vase: 0.331787109375
# gradient size average: 0.00035190582275390625
# weighted center col: 11.34375
# weighted center row: 9.15625
# weighted center col: 7.30859375
# weighted center row: 8.71875
# weighted center col: 7.33203125
# weighted center row: 7.74609375
# loss for robot: 0.1468505859375
# loss for blue: 0.39892578125
# loss for vase: 0.321533203125
# gradient size average: 0.00016057491302490234
# weighted center col: 11.3359375
# weighted center row: 9.09375
# weighted center col: 7.37109375
# weighted center row: 8.7578125
# weighted center col: 7.43359375
# weighted center row: 7.8046875
# loss for robot: 0.125
# loss for blue: 0.39794921875
# loss for vase: 0.324462890625
# gradient size average: 0.00010418891906738281
# weighted center col: 11.21875
# weighted center row: 8.96875
# weighted center col: 7.390625
# weighted center row: 8.78125
# weighted center col: 7.50390625
# weighted center row: 7.84375
# loss for robot: 0.1192626953125
# loss for blue: 0.3974609375
# loss for vase: 0.32666015625
# gradient size average: 9.02414321899414e-05
# weighted center col: 11.2890625
# weighted center row: 9.046875
# weighted center col: 7.33203125
# weighted center row: 8.890625
# weighted center col: 7.4453125
# weighted center row: 7.8203125
# loss for robot: 0.1195068359375
# loss for blue: 0.396728515625
# loss for vase: 0.324462890625
# gradient size average: 7.2479248046875e-05
# weighted center col: 11.2421875
# weighted center row: 8.9921875
# weighted center col: 7.31640625
# weighted center row: 8.953125
# weighted center col: 7.47265625
# weighted center row: 7.84375
# loss for robot: 0.1171875
# loss for blue: 0.395263671875
# loss for vase: 0.3251953125
# gradient size average: 7.241964340209961e-05
# weighted center col: 11.2890625
# weighted center row: 9.0234375
# weighted center col: 7.2890625
# weighted center row: 9.0390625
# weighted center col: 7.4375
# weighted center row: 7.8515625
# loss for robot: 0.11798095703125
# loss for blue: 0.39501953125
# loss for vase: 0.322998046875
# gradient size average: 6.282329559326172e-05
# weighted center col: 11.265625
# weighted center row: 9.0078125
# weighted center col: 7.265625
# weighted center row: 9.1171875
# weighted center col: 7.47265625
# weighted center row: 7.87890625
# loss for robot: 0.1162109375
# loss for blue: 0.393798828125
# loss for vase: 0.3232421875
# gradient size average: 6.175041198730469e-05
# weighted center col: 11.296875
# weighted center row: 9.0390625
# weighted center col: 7.234375
# weighted center row: 9.203125
# weighted center col: 7.42578125
# weighted center row: 7.8671875
# loss for robot: 0.116455078125
# loss for blue: 0.392822265625
# loss for vase: 0.322265625
# gradient size average: 7.909536361694336e-05
# weighted center col: 11.2734375
# weighted center row: 8.984375
# weighted center col: 7.26953125
# weighted center row: 9.0703125
# weighted center col: 7.4609375
# weighted center row: 7.88671875
# loss for robot: 0.1151123046875
# loss for blue: 0.394287109375
# loss for vase: 0.322021484375
# gradient size average: 6.455183029174805e-05
# weighted center col: 11.3203125
# weighted center row: 9.046875
# weighted center col: 7.24609375
# weighted center row: 9.15625
# weighted center col: 7.4375
# weighted center row: 7.8671875
# loss for robot: 0.114990234375
# loss for blue: 0.393310546875
# loss for vase: 0.3212890625
# gradient size average: 5.602836608886719e-05
# weighted center col: 11.296875
# weighted center row: 9.0078125
# weighted center col: 7.23046875
# weighted center row: 9.2265625
# weighted center col: 7.44140625
# weighted center row: 7.8671875
# loss for robot: 0.1142578125
# loss for blue: 0.3935546875
# loss for vase: 0.3212890625
# gradient size average: 6.914138793945312e-05
# weighted center col: 11.3125
# weighted center row: 8.9921875
# weighted center col: 7.2734375
# weighted center row: 9.0859375
# weighted center col: 7.42578125
# weighted center row: 7.88671875
# loss for robot: 0.11358642578125
# loss for blue: 0.394287109375
# loss for vase: 0.32080078125
# gradient size average: 5.2094459533691406e-05
# weighted center col: 11.3125
# weighted center row: 9.015625
# weighted center col: 7.22265625
# weighted center row: 9.171875
# weighted center col: 7.41796875
# weighted center row: 7.88671875
# loss for robot: 0.11395263671875
# loss for blue: 0.3935546875
# loss for vase: 0.319580078125
# gradient size average: 5.078315734863281e-05
# weighted center col: 11.3125
# weighted center row: 9.0078125
# weighted center col: 7.1953125
# weighted center row: 9.2265625
# weighted center col: 7.421875
# weighted center row: 7.88671875
# loss for robot: 0.11358642578125
# loss for blue: 0.393310546875
# loss for vase: 0.3193359375
# gradient size average: 6.669759750366211e-05
# weighted center col: 11.3203125
# weighted center row: 8.96875
# weighted center col: 7.2421875
# weighted center row: 9.109375
# weighted center col: 7.41015625
# weighted center row: 7.890625
# loss for robot: 0.11334228515625
# loss for blue: 0.39404296875
# loss for vase: 0.3193359375
# gradient size average: 5.143880844116211e-05
# weighted center col: 11.3125
# weighted center row: 9.015625
# weighted center col: 7.1953125
# weighted center row: 9.1796875
# weighted center col: 7.3984375
# weighted center row: 7.875
# loss for robot: 0.11297607421875
# loss for blue: 0.39306640625
# loss for vase: 0.318603515625
# gradient size average: 4.941225051879883e-05
# weighted center col: 11.3203125
# weighted center row: 8.9921875
# weighted center col: 7.17578125
# weighted center row: 9.265625
# weighted center col: 7.38671875
# weighted center row: 7.875
# loss for robot: 0.11328125
# loss for blue: 0.394287109375
# loss for vase: 0.318603515625
# gradient size average: 6.520748138427734e-05
# weighted center col: 11.34375
# weighted center row: 9.0078125
# weighted center col: 7.20703125
# weighted center row: 9.1328125
# weighted center col: 7.3828125
# weighted center row: 7.8984375
# loss for robot: 0.1121826171875
# loss for blue: 0.3935546875
# loss for vase: 0.318359375
# gradient size average: 4.929304122924805e-05
# weighted center col: 11.3359375
# weighted center row: 9.015625
# weighted center col: 7.18359375
# weighted center row: 9.21875
# weighted center col: 7.3828125
# weighted center row: 7.9140625
# loss for robot: 0.1124267578125
# loss for blue: 0.393798828125
# loss for vase: 0.317138671875
# gradient size average: 6.449222564697266e-05
# weighted center col: 11.3515625
# weighted center row: 9.0078125
# weighted center col: 7.2109375
# weighted center row: 9.1015625
# weighted center col: 7.375
# weighted center row: 7.90625
# loss for robot: 0.11163330078125
# loss for blue: 0.39404296875
# loss for vase: 0.31689453125
# gradient size average: 4.857778549194336e-05
# weighted center col: 11.34375
# weighted center row: 9.015625
# weighted center col: 7.18359375
# weighted center row: 9.171875
# weighted center col: 7.37109375
# weighted center row: 7.91796875
# loss for robot: 0.11163330078125
# loss for blue: 0.393310546875
# loss for vase: 0.31640625
# gradient size average: 4.786252975463867e-05
# weighted center col: 11.3515625
# weighted center row: 9.03125
# weighted center col: 7.14453125
# weighted center row: 9.2421875
# weighted center col: 7.37109375
# weighted center row: 7.91796875
# loss for robot: 0.111328125
# loss for blue: 0.394287109375
# loss for vase: 0.3154296875
# gradient size average: 6.455183029174805e-05
# weighted center col: 11.328125
# weighted center row: 8.9921875
# weighted center col: 7.1796875
# weighted center row: 9.109375
# weighted center col: 7.34765625
# weighted center row: 7.9296875
# loss for robot: 0.11151123046875
# loss for blue: 0.394287109375
# loss for vase: 0.315185546875
# gradient size average: 4.83393669128418e-05
# weighted center col: 11.3671875
# weighted center row: 9.0234375
# weighted center col: 7.15625
# weighted center row: 9.1875
# weighted center col: 7.3359375
# weighted center row: 7.921875
# loss for robot: 0.111328125
# loss for blue: 0.393798828125
# loss for vase: 0.31494140625
# gradient size average: 4.8220157623291016e-05
# 	 Exceeded max number of iterations (25)!
# weighted center col: 11.359375
# weighted center row: 9.0
# weighted center col: 7.109375
# weighted center row: 9.2578125
# weighted center col: 7.32421875
# weighted center row: 7.92578125
# loss for robot: 0.11181640625
# loss for blue: 0.39404296875
# loss for vase: 0.31396484375
# 	 Finished with loss of: tensor([0.8198], device='cuda:0', grad_fn=<AddBackward0>)
# loss for robot: 0.11181640625
# loss for blue: 0.39404296875
# loss for vase: 0.31396484375
# gradient size average: 6.61611557006836e-05
# Iteration 2 | Loss: 0.8198
# weighted center col: 11.2421875
# weighted center row: 8.9375
# weighted center col: 7.33203125
# weighted center row: 8.7109375
# weighted center col: 7.34375
# weighted center row: 7.9453125
# loss for robot: 0.11578369140625
# loss for blue: 0.3974609375
# loss for vase: 0.31298828125
# loss for robot: 0.11578369140625
# loss for blue: 0.3974609375
# loss for vase: 0.31298828125
# gradient size average: 0.00010377168655395508
# Iteration 3 | Loss: 0.8262
# weighted center col: 11.328125
# weighted center row: 9.0859375
# weighted center col: 7.38671875
# weighted center row: 8.4453125
# weighted center col: 7.27734375
# weighted center row: 7.97265625
# loss for robot: 0.12249755859375
# loss for blue: 0.3994140625
# loss for vase: 0.3076171875
# weighted center col: 11.328125
# weighted center row: 9.0859375
# weighted center col: 7.38671875
# weighted center row: 8.4453125
# weighted center col: 7.27734375
# weighted center row: 7.97265625
# loss for robot: 0.12249755859375
# loss for blue: 0.3994140625
# loss for vase: 0.3076171875
# gradient size average: 8.815526962280273e-05
# weighted center col: 11.28125
# weighted center row: 8.96875
# weighted center col: 7.375
# weighted center row: 8.5390625
# weighted center col: 7.33984375
# weighted center row: 8.0078125
# loss for robot: 0.11822509765625
# loss for blue: 0.3984375
# loss for vase: 0.308837890625
# gradient size average: 6.633996963500977e-05
# weighted center col: 11.28125
# weighted center row: 8.9765625
# weighted center col: 7.3359375
# weighted center row: 8.6015625
# weighted center col: 7.32421875
# weighted center row: 8.015625
# loss for robot: 0.1170654296875
# loss for blue: 0.397705078125
# loss for vase: 0.308349609375
# gradient size average: 6.383657455444336e-05
# weighted center col: 11.296875
# weighted center row: 8.96875
# weighted center col: 7.2890625
# weighted center row: 8.65625
# weighted center col: 7.296875
# weighted center row: 8.0
# loss for robot: 0.11669921875
# loss for blue: 0.396240234375
# loss for vase: 0.3076171875
# gradient size average: 6.29425048828125e-05
# weighted center col: 11.3046875
# weighted center row: 8.984375
# weighted center col: 7.2421875
# weighted center row: 8.734375
# weighted center col: 7.2734375
# weighted center row: 8.015625
# loss for robot: 0.115966796875
# loss for blue: 0.3955078125
# loss for vase: 0.306396484375
# gradient size average: 6.23464584350586e-05
# weighted center col: 11.3125
# weighted center row: 8.984375
# weighted center col: 7.21484375
# weighted center row: 8.78125
# weighted center col: 7.2734375
# weighted center row: 8.0234375
# loss for robot: 0.115478515625
# loss for blue: 0.394775390625
# loss for vase: 0.30517578125
# gradient size average: 6.175041198730469e-05
# weighted center col: 11.3046875
# weighted center row: 8.9921875
# weighted center col: 7.19140625
# weighted center row: 8.8515625
# weighted center col: 7.25
# weighted center row: 8.015625
# loss for robot: 0.11529541015625
# loss for blue: 0.394287109375
# loss for vase: 0.303955078125
# gradient size average: 6.103515625e-05
# weighted center col: 11.3046875
# weighted center row: 9.0
# weighted center col: 7.15625
# weighted center row: 8.921875
# weighted center col: 7.2578125
# weighted center row: 8.015625
# loss for robot: 0.114990234375
# loss for blue: 0.394287109375
# loss for vase: 0.30322265625
# gradient size average: 6.014108657836914e-05
# weighted center col: 11.3203125
# weighted center row: 9.0078125
# weighted center col: 7.09765625
# weighted center row: 8.9765625
# weighted center col: 7.2421875
# weighted center row: 8.015625
# loss for robot: 0.11474609375
# loss for blue: 0.393310546875
# loss for vase: 0.30224609375
# gradient size average: 5.942583084106445e-05
# weighted center col: 11.296875
# weighted center row: 9.015625
# weighted center col: 7.06640625
# weighted center row: 9.03125
# weighted center col: 7.234375
# weighted center row: 8.0390625
# loss for robot: 0.114501953125
# loss for blue: 0.392822265625
# loss for vase: 0.30078125
# gradient size average: 5.888938903808594e-05
# weighted center col: 11.28125
# weighted center row: 9.0078125
# weighted center col: 7.02734375
# weighted center row: 9.125
# weighted center col: 7.2265625
# weighted center row: 8.03125
# loss for robot: 0.1146240234375
# loss for blue: 0.39111328125
# loss for vase: 0.300048828125
# gradient size average: 5.793571472167969e-05
# weighted center col: 11.28125
# weighted center row: 9.015625
# weighted center col: 7.015625
# weighted center row: 9.171875
# weighted center col: 7.21875
# weighted center row: 8.03125
# loss for robot: 0.114501953125
# loss for blue: 0.3896484375
# loss for vase: 0.298828125
# gradient size average: 5.7578086853027344e-05
# weighted center col: 11.2890625
# weighted center row: 9.0
# weighted center col: 6.97265625
# weighted center row: 9.2265625
# weighted center col: 7.19921875
# weighted center row: 8.046875
# loss for robot: 0.11474609375
# loss for blue: 0.39013671875
# loss for vase: 0.297607421875
# gradient size average: 6.783008575439453e-05
# weighted center col: 11.28125
# weighted center row: 8.984375
# weighted center col: 7.0078125
# weighted center row: 9.1015625
# weighted center col: 7.1796875
# weighted center row: 8.0703125
# loss for robot: 0.11468505859375
# loss for blue: 0.390869140625
# loss for vase: 0.2958984375
# gradient size average: 5.78761100769043e-05
# weighted center col: 11.296875
# weighted center row: 8.9921875
# weighted center col: 6.984375
# weighted center row: 9.171875
# weighted center col: 7.18359375
# weighted center row: 8.0703125
# loss for robot: 0.11431884765625
# loss for blue: 0.39013671875
# loss for vase: 0.29541015625
# gradient size average: 5.626678466796875e-05
# weighted center col: 11.296875
# weighted center row: 9.0078125
# weighted center col: 6.95703125
# weighted center row: 9.25
# weighted center col: 7.15625
# weighted center row: 8.0703125
# loss for robot: 0.11395263671875
# loss for blue: 0.39013671875
# loss for vase: 0.294189453125
# gradient size average: 6.759166717529297e-05
# weighted center col: 11.3046875
# weighted center row: 8.9765625
# weighted center col: 6.98828125
# weighted center row: 9.09375
# weighted center col: 7.14453125
# weighted center row: 8.1015625
# loss for robot: 0.1143798828125
# loss for blue: 0.390625
# loss for vase: 0.292236328125
# gradient size average: 5.7697296142578125e-05
# weighted center col: 11.28125
# weighted center row: 8.96875
# weighted center col: 6.953125
# weighted center row: 9.1953125
# weighted center col: 7.1328125
# weighted center row: 8.109375
# loss for robot: 0.11456298828125
# loss for blue: 0.389404296875
# loss for vase: 0.2919921875
# gradient size average: 5.53131103515625e-05
# weighted center col: 11.2890625
# weighted center row: 8.9609375
# weighted center col: 6.90625
# weighted center row: 9.265625
# weighted center col: 7.125
# weighted center row: 8.1171875
# loss for robot: 0.1146240234375
# loss for blue: 0.390625
# loss for vase: 0.291015625
# gradient size average: 6.693601608276367e-05
# weighted center col: 11.3046875
# weighted center row: 8.9609375
# weighted center col: 6.95703125
# weighted center row: 9.109375
# weighted center col: 7.12890625
# weighted center row: 8.1171875
# loss for robot: 0.11468505859375
# loss for blue: 0.39111328125
# loss for vase: 0.2890625
# gradient size average: 5.6743621826171875e-05
# weighted center col: 11.2890625
# weighted center row: 8.9765625
# weighted center col: 6.90234375
# weighted center row: 9.2109375
# weighted center col: 7.1015625
# weighted center row: 8.1171875
# loss for robot: 0.11431884765625
# loss for blue: 0.389892578125
# loss for vase: 0.2890625
# gradient size average: 6.562471389770508e-05
# weighted center col: 11.3046875
# weighted center row: 8.9453125
# weighted center col: 6.953125
# weighted center row: 9.0390625
# weighted center col: 7.12109375
# weighted center row: 8.140625
# loss for robot: 0.11492919921875
# loss for blue: 0.391357421875
# loss for vase: 0.287353515625
# gradient size average: 5.739927291870117e-05
# weighted center col: 11.28125
# weighted center row: 8.9609375
# weighted center col: 6.90625
# weighted center row: 9.15625
# weighted center col: 7.1015625
# weighted center row: 8.1484375
# loss for robot: 0.11480712890625
# loss for blue: 0.389892578125
# loss for vase: 0.286865234375
# gradient size average: 5.364418029785156e-05
# weighted center col: 11.2890625
# weighted center row: 8.9765625
# weighted center col: 6.875
# weighted center row: 9.234375
# weighted center col: 7.08203125
# weighted center row: 8.1484375
# loss for robot: 0.11474609375
# loss for blue: 0.38916015625
# loss for vase: 0.2861328125
# gradient size average: 6.41942024230957e-05
# weighted center col: 11.3046875
# weighted center row: 8.9765625
# weighted center col: 6.8984375
# weighted center row: 9.078125
# weighted center col: 7.0859375
# weighted center row: 8.15625
# loss for robot: 0.114501953125
# loss for blue: 0.390380859375
# loss for vase: 0.284423828125
# gradient size average: 5.644559860229492e-05
# 	 Exceeded max number of iterations (25)!
# weighted center col: 11.2890625
# weighted center row: 8.9921875
# weighted center col: 6.84375
# weighted center row: 9.1796875
# weighted center col: 7.07421875
# weighted center row: 8.15625
# loss for robot: 0.1141357421875
# loss for blue: 0.38818359375
# loss for vase: 0.284423828125
# 	 Finished with loss of: tensor([0.7871], device='cuda:0', grad_fn=<AddBackward0>)
# loss for robot: 0.1141357421875
# loss for blue: 0.38818359375
# loss for vase: 0.284423828125
# gradient size average: 5.3882598876953125e-05
# Iteration 4 | Loss: 0.7871
# weighted center col: 11.328125
# weighted center row: 9.03125
# weighted center col: 7.015625
# weighted center row: 8.84375
# weighted center col: 7.0234375
# weighted center row: 8.1640625
# loss for robot: 0.11968994140625
# loss for blue: 0.392333984375
# loss for vase: 0.27880859375
# loss for robot: 0.11968994140625
# loss for blue: 0.392333984375
# loss for vase: 0.27880859375
# gradient size average: 8.32676887512207e-05
# Iteration 5 | Loss: 0.7905
# weighted center col: 11.375
# weighted center row: 9.0
# weighted center col: 7.1796875
# weighted center row: 8.609375
# weighted center col: 7.0078125
# weighted center row: 8.140625
# loss for robot: 0.12249755859375
# loss for blue: 0.3955078125
# loss for vase: 0.275634765625
# loss for robot: 0.12249755859375
# loss for blue: 0.3955078125
# loss for vase: 0.275634765625
# gradient size average: 8.07642936706543e-05
# Iteration 6 | Loss: 0.7935
# weighted center col: 11.421875
# weighted center row: 8.9765625
# weighted center col: 7.3203125
# weighted center row: 8.4375
# weighted center col: 6.96875
# weighted center row: 8.109375
# loss for robot: 0.1253662109375
# loss for blue: 0.3974609375
# loss for vase: 0.27197265625
# loss for robot: 0.1253662109375
# loss for blue: 0.3974609375
# loss for vase: 0.27197265625
# gradient size average: 8.028745651245117e-05
# Iteration 7 | Loss: 0.7949
# weighted center col: 11.4765625
# weighted center row: 9.0234375
# weighted center col: 7.4140625
# weighted center row: 8.3125
# weighted center col: 6.9375
# weighted center row: 8.078125
# loss for robot: 0.1295166015625
# loss for blue: 0.39794921875
# loss for vase: 0.26953125
# loss for robot: 0.1295166015625
# loss for blue: 0.39794921875
# loss for vase: 0.26953125
# gradient size average: 9.584426879882812e-05
# Iteration 8 | Loss: 0.7969
# weighted center col: 11.5703125
# weighted center row: 9.125
# weighted center col: 7.421875
# weighted center row: 8.25
# weighted center col: 6.91796875
# weighted center row: 8.0390625
# loss for robot: 0.136474609375
# loss for blue: 0.396728515625
# loss for vase: 0.268798828125
# loss for robot: 0.136474609375
# loss for blue: 0.396728515625
# loss for vase: 0.268798828125
# gradient size average: 0.00012445449829101562
# Iteration 9 | Loss: 0.8018
# weighted center col: 11.65625
# weighted center row: 9.203125
# weighted center col: 7.4140625
# weighted center row: 8.203125
# weighted center col: 6.9140625
# weighted center row: 8.0390625
# loss for robot: 0.1429443359375
# loss for blue: 0.393798828125
# loss for vase: 0.26806640625
# loss for robot: 0.1429443359375
# loss for blue: 0.393798828125
# loss for vase: 0.26806640625
# gradient size average: 0.00014269351959228516
# Iteration 10 | Loss: 0.8052
# weighted center col: 11.71875
# weighted center row: 9.296875
# weighted center col: 7.39453125
# weighted center row: 8.15625
# weighted center col: 6.9375
# weighted center row: 7.984375
# loss for robot: 0.15185546875
# loss for blue: 0.390625
# loss for vase: 0.27001953125
# loss for robot: 0.15185546875
# loss for blue: 0.390625
# loss for vase: 0.27001953125
# gradient size average: 0.00011855363845825195
# Iteration 11 | Loss: 0.8125
# weighted center col: 11.75
# weighted center row: 9.3984375
# weighted center col: 7.37890625
# weighted center row: 8.15625
# weighted center col: 6.94921875
# weighted center row: 7.890625
# loss for robot: 0.162353515625
# loss for blue: 0.38623046875
# loss for vase: 0.27392578125
# loss for robot: 0.162353515625
# loss for blue: 0.38623046875
# loss for vase: 0.27392578125
# gradient size average: 7.683038711547852e-05
# Iteration 12 | Loss: 0.8223
# weighted center col: 11.75
# weighted center row: 9.4609375
# weighted center col: 7.3671875
# weighted center row: 8.109375
# weighted center col: 6.921875
# weighted center row: 7.8125
# loss for robot: 0.169677734375
# loss for blue: 0.38232421875
# loss for vase: 0.278564453125
# loss for robot: 0.169677734375
# loss for blue: 0.38232421875
# loss for vase: 0.278564453125
# gradient size average: 7.039308547973633e-05
# Iteration 13 | Loss: 0.8311
# weighted center col: 11.75
# weighted center row: 9.453125
# weighted center col: 7.37109375
# weighted center row: 8.1484375
# weighted center col: 6.921875
# weighted center row: 7.72265625
# loss for robot: 0.171630859375
# loss for blue: 0.37841796875
# loss for vase: 0.284912109375
# loss for robot: 0.171630859375
# loss for blue: 0.37841796875
# loss for vase: 0.284912109375
# gradient size average: 7.575750350952148e-05
# Iteration 14 | Loss: 0.8350
# weighted center col: 11.6953125
# weighted center row: 9.4140625
# weighted center col: 7.390625
# weighted center row: 8.109375
# weighted center col: 6.953125
# weighted center row: 7.63671875
# loss for robot: 0.1717529296875
# loss for blue: 0.375244140625
# loss for vase: 0.29150390625
# loss for robot: 0.1717529296875
# loss for blue: 0.375244140625
# loss for vase: 0.29150390625
# gradient size average: 8.350610733032227e-05
# Iteration 15 | Loss: 0.8389
# weighted center col: 11.625
# weighted center row: 9.3828125
# weighted center col: 7.44140625
# weighted center row: 8.1171875
# weighted center col: 6.96484375
# weighted center row: 7.55078125
# loss for robot: 0.1717529296875
# loss for blue: 0.37353515625
# loss for vase: 0.297607421875
# loss for robot: 0.1717529296875
# loss for blue: 0.37353515625
# loss for vase: 0.297607421875
# gradient size average: 8.934736251831055e-05
# Iteration 16 | Loss: 0.8428
# weighted center col: 11.6328125
# weighted center row: 9.3359375
# weighted center col: 7.4609375
# weighted center row: 8.140625
# weighted center col: 6.9609375
# weighted center row: 7.45703125
# loss for robot: 0.171630859375
# loss for blue: 0.371337890625
# loss for vase: 0.3037109375
# loss for robot: 0.171630859375
# loss for blue: 0.371337890625
# loss for vase: 0.3037109375
# gradient size average: 9.340047836303711e-05
# Iteration 17 | Loss: 0.8467
# weighted center col: 11.5703125
# weighted center row: 9.2578125
# weighted center col: 7.4453125
# weighted center row: 8.0703125
# weighted center col: 6.95703125
# weighted center row: 7.359375
# loss for robot: 0.170654296875
# loss for blue: 0.370361328125
# loss for vase: 0.30908203125
# loss for robot: 0.170654296875
# loss for blue: 0.370361328125
# loss for vase: 0.30908203125
# gradient size average: 9.703636169433594e-05
# Iteration 18 | Loss: 0.8506
# weighted center col: 11.546875
# weighted center row: 9.25
# weighted center col: 7.4609375
# weighted center row: 8.0703125
# weighted center col: 6.9296875
# weighted center row: 7.296875
# loss for robot: 0.1705322265625
# loss for blue: 0.369384765625
# loss for vase: 0.314453125
# loss for robot: 0.1705322265625
# loss for blue: 0.369384765625
# loss for vase: 0.314453125
# gradient size average: 9.578466415405273e-05
# Iteration 19 | Loss: 0.8540
# weighted center col: 11.5625
# weighted center row: 9.2578125
# weighted center col: 7.44921875
# weighted center row: 8.0703125
# weighted center col: 6.921875
# weighted center row: 7.23828125
# loss for robot: 0.1707763671875
# loss for blue: 0.368896484375
# loss for vase: 0.316650390625
# loss for robot: 0.1707763671875
# loss for blue: 0.368896484375
# loss for vase: 0.316650390625
# gradient size average: 9.733438491821289e-05
# Iteration 20 | Loss: 0.8564
# weighted center col: 11.546875
# weighted center row: 9.2421875
# weighted center col: 7.44921875
# weighted center row: 8.0234375
# weighted center col: 6.9453125
# weighted center row: 7.1953125
# loss for robot: 0.1708984375
# loss for blue: 0.369140625
# loss for vase: 0.317138671875
# loss for robot: 0.1708984375
# loss for blue: 0.369140625
# loss for vase: 0.317138671875
# gradient size average: 9.870529174804688e-05
# Iteration 21 | Loss: 0.8574
# weighted center col: 11.5625
# weighted center row: 9.25
# weighted center col: 7.4609375
# weighted center row: 7.99609375
# weighted center col: 6.94921875
# weighted center row: 7.19921875
# loss for robot: 0.1710205078125
# loss for blue: 0.368896484375
# loss for vase: 0.317138671875
# loss for robot: 0.1710205078125
# loss for blue: 0.368896484375
# loss for vase: 0.317138671875
# gradient size average: 9.98377799987793e-05
# Iteration 22 | Loss: 0.8569
# weighted center col: 11.5703125
# weighted center row: 9.234375
# weighted center col: 7.47265625
# weighted center row: 7.97265625
# weighted center col: 6.9296875
# weighted center row: 7.19921875
# loss for robot: 0.1700439453125
# loss for blue: 0.368896484375
# loss for vase: 0.31689453125
# loss for robot: 0.1700439453125
# loss for blue: 0.368896484375
# loss for vase: 0.31689453125
# gradient size average: 0.0001023411750793457
# Iteration 23 | Loss: 0.8555
# weighted center col: 11.5703125
# weighted center row: 9.234375
# weighted center col: 7.484375
# weighted center row: 7.97265625
# weighted center col: 6.9375
# weighted center row: 7.19140625
# loss for robot: 0.1688232421875
# loss for blue: 0.368896484375
# loss for vase: 0.31591796875
# loss for robot: 0.1688232421875
# loss for blue: 0.368896484375
# loss for vase: 0.31591796875
# gradient size average: 0.00010722875595092773
# Iteration 24 | Loss: 0.8535
# weighted center col: 11.5625
# weighted center row: 9.21875
# weighted center col: 7.50390625
# weighted center row: 7.98046875
# weighted center col: 6.92578125
# weighted center row: 7.19921875
# loss for robot: 0.16748046875
# loss for blue: 0.369384765625
# loss for vase: 0.31201171875
# weighted center col: 11.59375
# weighted center row: 9.265625
# weighted center col: 7.48046875
# weighted center row: 7.9296875
# weighted center col: 6.9296875
# weighted center row: 7.16796875
# loss for robot: 0.17041015625
# loss for blue: 0.369384765625
# loss for vase: 0.318603515625
# weighted center col: 11.609375
# weighted center row: 9.3046875
# weighted center col: 7.484375
# weighted center row: 7.921875
# weighted center col: 6.9453125
# weighted center row: 7.08984375
# loss for robot: 0.171875
# loss for blue: 0.369384765625
# loss for vase: 0.326171875
# weighted center col: 11.625
# weighted center row: 9.3125
# weighted center col: 7.4921875
# weighted center row: 7.91796875
# weighted center col: 6.97265625
# weighted center row: 7.078125
# loss for robot: 0.17138671875
# loss for blue: 0.369384765625
# loss for vase: 0.332763671875
# weighted center col: 11.6015625
# weighted center row: 9.3046875
# weighted center col: 7.484375
# weighted center row: 7.921875
# weighted center col: 7.02734375
# weighted center row: 7.046875
# loss for robot: 0.17041015625
# loss for blue: 0.369140625
# loss for vase: 0.341064453125
# weighted center col: 11.609375
# weighted center row: 9.296875
# weighted center col: 7.48046875
# weighted center row: 7.921875
# weighted center col: 7.0390625
# weighted center row: 6.9921875
# loss for robot: 0.1693115234375
# loss for blue: 0.36865234375
# loss for vase: 0.34716796875
# weighted center col: 11.5859375
# weighted center row: 9.2890625
# weighted center col: 7.4921875
# weighted center row: 7.91796875
# weighted center col: 7.0625
# weighted center row: 7.01953125
# loss for robot: 0.1683349609375
# loss for blue: 0.36865234375
# loss for vase: 0.3515625
# weighted center col: 11.6015625
# weighted center row: 9.28125
# weighted center col: 7.4921875
# weighted center row: 7.91796875
# weighted center col: 7.08203125
# weighted center row: 6.98046875
# loss for robot: 0.1668701171875
# loss for blue: 0.36865234375
# loss for vase: 0.35546875
# weighted center col: 11.609375
# weighted center row: 9.28125
# weighted center col: 7.48828125
# weighted center row: 7.90625
# weighted center col: 7.07421875
# weighted center row: 6.96875
# loss for robot: 0.1656494140625
# loss for blue: 0.369384765625
# loss for vase: 0.357666015625
# weighted center col: 11.6015625
# weighted center row: 9.25
# weighted center col: 7.49609375
# weighted center row: 7.90625
# weighted center col: 7.09375
# weighted center row: 6.953125
# loss for robot: 0.164306640625
# loss for blue: 0.369873046875
# loss for vase: 0.35986328125
# weighted center col: 11.609375
# weighted center row: 9.2421875
# weighted center col: 7.52734375
# weighted center row: 7.91015625
# weighted center col: 7.1328125
# weighted center row: 6.98046875
# loss for robot: 0.1629638671875
# loss for blue: 0.370361328125
# loss for vase: 0.361083984375
# weighted center col: 11.6015625
# weighted center row: 9.234375
# weighted center col: 7.53515625
# weighted center row: 7.921875
# weighted center col: 7.1640625
# weighted center row: 6.9765625
# loss for robot: 0.16162109375
# loss for blue: 0.3701171875
# loss for vase: 0.36328125
# weighted center col: 11.609375
# weighted center row: 9.2109375
# weighted center col: 7.515625
# weighted center row: 7.9140625
# weighted center col: 7.17578125
# weighted center row: 7.0078125
# loss for robot: 0.159912109375
# loss for blue: 0.370849609375
# loss for vase: 0.365478515625
# weighted center col: 11.5703125
# weighted center row: 9.171875
# weighted center col: 7.546875
# weighted center row: 7.87890625
# weighted center col: 7.19140625
# weighted center row: 7.0078125
# loss for robot: 0.15869140625
# loss for blue: 0.371826171875
# loss for vase: 0.36669921875
# weighted center col: 11.546875
# weighted center row: 9.1796875
# weighted center col: 7.578125
# weighted center row: 7.890625
# weighted center col: 7.234375
# weighted center row: 7.06640625
# loss for robot: 0.15673828125
# loss for blue: 0.372314453125
# loss for vase: 0.366943359375
# weighted center col: 11.515625
# weighted center row: 9.125
# weighted center col: 7.59765625
# weighted center row: 7.89453125
# weighted center col: 7.23828125
# weighted center row: 7.11328125
# loss for robot: 0.1549072265625
# loss for blue: 0.372314453125
# loss for vase: 0.365966796875
# weighted center col: 11.4765625
# weighted center row: 9.1171875
# weighted center col: 7.62109375
# weighted center row: 7.9296875
# weighted center col: 7.3203125
# weighted center row: 7.14453125
# loss for robot: 0.1522216796875
# loss for blue: 0.37255859375
# loss for vase: 0.365478515625
# weighted center col: 11.4296875
# weighted center row: 9.1015625
# weighted center col: 7.6328125
# weighted center row: 7.94921875
# weighted center col: 7.328125
# weighted center row: 7.24609375
# loss for robot: 0.1490478515625
# loss for blue: 0.373046875
# loss for vase: 0.3642578125
# weighted center col: 11.375
# weighted center row: 9.0625
# weighted center col: 7.65625
# weighted center row: 7.94140625
# weighted center col: 7.35546875
# weighted center row: 7.3125
# loss for robot: 0.14599609375
# loss for blue: 0.373779296875
# loss for vase: 0.364990234375
# weighted center col: 11.34375
# weighted center row: 9.0546875
# weighted center col: 7.6875
# weighted center row: 7.9375
# weighted center col: 7.421875
# weighted center row: 7.36328125
# loss for robot: 0.141845703125
# loss for blue: 0.375
# loss for vase: 0.365966796875
# weighted center col: 11.28125
# weighted center row: 9.109375
# weighted center col: 7.71875
# weighted center row: 7.94921875
# weighted center col: 7.4609375
# weighted center row: 7.46875
# loss for robot: 0.1383056640625
# loss for blue: 0.375732421875
# loss for vase: 0.365234375
# weighted center col: 11.234375
# weighted center row: 9.1171875
# weighted center col: 7.73046875
# weighted center row: 7.90234375
# weighted center col: 7.51171875
# weighted center row: 7.50390625
# loss for robot: 0.13720703125
# loss for blue: 0.3759765625
# loss for vase: 0.365966796875
# weighted center col: 11.203125
# weighted center row: 9.109375
# weighted center col: 7.7734375
# weighted center row: 7.8984375
# weighted center col: 7.55859375
# weighted center row: 7.65625
# loss for robot: 0.1375732421875
# loss for blue: 0.375244140625
# loss for vase: 0.365234375
# weighted center col: 11.1015625
# weighted center row: 8.9921875
# weighted center col: 7.8359375
# weighted center row: 7.8984375
# weighted center col: 7.61328125
# weighted center row: 7.71875
# loss for robot: 0.143310546875
# loss for blue: 0.37353515625
# loss for vase: 0.367919921875
# weighted center col: 10.5625
# weighted center row: 8.71875
# weighted center col: 8.0078125
# weighted center row: 8.015625
# weighted center col: 7.79296875
# weighted center row: 7.95703125
# loss for robot: 0.1776123046875
# loss for blue: 0.3740234375
# loss for vase: 0.3681640625

# %%
#display image 

from IPython.display import Image
Image(str(image_path))
# Out:
# ls: cannot access 'outputs3/a _robot__54,_3,_4,_55_ and a _blue vase__14,_3,_4,_55_/42.png': No such file or directory
# outputs3/a _robot__54,_3,_4,_55_ and a _blue vase__14,_3,_4,_55_/42.png
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /usr/local/lib/python3.9/dist-packages/IPython/core/display.py:1300 in _data_and_metadata        │
# │                                                                                                  │
# │   1297 │   def _data_and_metadata(self, always_both=False):                                      │
# │   1298 │   │   """shortcut for returning metadata with shape information, if defined"""          │
# │   1299 │   │   try:                                                                              │
# │ ❱ 1300 │   │   │   b64_data = b2a_base64(self.data).decode('ascii')                              │
# │   1301 │   │   except TypeError:                                                                 │
# │   1302 │   │   │   raise FileNotFoundError(                                                      │
# │   1303 │   │   │   │   "No such file or directory: '%s'" % (self.data))                          │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /usr/local/lib/python3.9/dist-packages/IPython/core/formatters.py:224 in catch_format_error      │
# │                                                                                                  │
# │    221 def catch_format_error(method, self, *args, **kwargs):                                    │
# │    222 │   """show traceback on failed format call"""                                            │
# │    223 │   try:                                                                                  │
# │ ❱  224 │   │   r = method(self, *args, **kwargs)                                                 │
# │    225 │   except NotImplementedError:                                                           │
# │    226 │   │   # don't warn on NotImplementedErrors                                              │
# │    227 │   │   return self._check_return(None, args[0])                                          │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/IPython/core/formatters.py:970 in __call__                │
# │                                                                                                  │
# │    967 │   │   │   method = get_real_method(obj, self.print_method)                              │
# │    968 │   │   │                                                                                 │
# │    969 │   │   │   if method is not None:                                                        │
# │ ❱  970 │   │   │   │   return method(include=include, exclude=exclude)                           │
# │    971 │   │   │   return None                                                                   │
# │    972 │   │   else:                                                                             │
# │    973 │   │   │   return None                                                                   │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/IPython/core/display.py:1290 in _repr_mimebundle_         │
# │                                                                                                  │
# │   1287 │   │   """                                                                               │
# │   1288 │   │   if self.embed:                                                                    │
# │   1289 │   │   │   mimetype = self._mimetype                                                     │
# │ ❱ 1290 │   │   │   data, metadata = self._data_and_metadata(always_both=True)                    │
# │   1291 │   │   │   if metadata:                                                                  │
# │   1292 │   │   │   │   metadata = {mimetype: metadata}                                           │
# │   1293 │   │   │   return {mimetype: data}, metadata                                             │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/IPython/core/display.py:1302 in _data_and_metadata        │
# │                                                                                                  │
# │   1299 │   │   try:                                                                              │
# │   1300 │   │   │   b64_data = b2a_base64(self.data).decode('ascii')                              │
# │   1301 │   │   except TypeError:                                                                 │
# │ ❱ 1302 │   │   │   raise FileNotFoundError(                                                      │
# │   1303 │   │   │   │   "No such file or directory: '%s'" % (self.data))                          │
# │   1304 │   │   md = {}                                                                           │
# │   1305 │   │   if self.metadata:                                                                 │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# FileNotFoundError: No such file or directory: 'outputs3/a _robot__54,_3,_4,_55_ and a _blue
# vase__14,_3,_4,_55_/42.png'
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /usr/local/lib/python3.9/dist-packages/IPython/core/display.py:1300 in _data_and_metadata        │
# │                                                                                                  │
# │   1297 │   def _data_and_metadata(self, always_both=False):                                      │
# │   1298 │   │   """shortcut for returning metadata with shape information, if defined"""          │
# │   1299 │   │   try:                                                                              │
# │ ❱ 1300 │   │   │   b64_data = b2a_base64(self.data).decode('ascii')                              │
# │   1301 │   │   except TypeError:                                                                 │
# │   1302 │   │   │   raise FileNotFoundError(                                                      │
# │   1303 │   │   │   │   "No such file or directory: '%s'" % (self.data))                          │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /usr/local/lib/python3.9/dist-packages/IPython/core/formatters.py:224 in catch_format_error      │
# │                                                                                                  │
# │    221 def catch_format_error(method, self, *args, **kwargs):                                    │
# │    222 │   """show traceback on failed format call"""                                            │
# │    223 │   try:                                                                                  │
# │ ❱  224 │   │   r = method(self, *args, **kwargs)                                                 │
# │    225 │   except NotImplementedError:                                                           │
# │    226 │   │   # don't warn on NotImplementedErrors                                              │
# │    227 │   │   return self._check_return(None, args[0])                                          │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/IPython/core/formatters.py:345 in __call__                │
# │                                                                                                  │
# │    342 │   │   │   # Finally look for special method names                                       │
# │    343 │   │   │   method = get_real_method(obj, self.print_method)                              │
# │    344 │   │   │   if method is not None:                                                        │
# │ ❱  345 │   │   │   │   return method()                                                           │
# │    346 │   │   │   return None                                                                   │
# │    347 │   │   else:                                                                             │
# │    348 │   │   │   return None                                                                   │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/IPython/core/display.py:1320 in _repr_png_                │
# │                                                                                                  │
# │   1317 │                                                                                         │
# │   1318 │   def _repr_png_(self):                                                                 │
# │   1319 │   │   if self.embed and self.format == self._FMT_PNG:                                   │
# │ ❱ 1320 │   │   │   return self._data_and_metadata()                                              │
# │   1321 │                                                                                         │
# │   1322 │   def _repr_jpeg_(self):                                                                │
# │   1323 │   │   if self.embed and self.format == self._FMT_JPEG:                                  │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/IPython/core/display.py:1302 in _data_and_metadata        │
# │                                                                                                  │
# │   1299 │   │   try:                                                                              │
# │   1300 │   │   │   b64_data = b2a_base64(self.data).decode('ascii')                              │
# │   1301 │   │   except TypeError:                                                                 │
# │ ❱ 1302 │   │   │   raise FileNotFoundError(                                                      │
# │   1303 │   │   │   │   "No such file or directory: '%s'" % (self.data))                          │
# │   1304 │   │   md = {}                                                                           │
# │   1305 │   │   if self.metadata:                                                                 │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# FileNotFoundError: No such file or directory: 'outputs3/a _robot__54,_3,_4,_55_ and a _blue
# vase__14,_3,_4,_55_/42.png'
